# %%
# %pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/ssharma/Desktop/python_tutorial/data_science/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# Dataframe -> Pandas Class which holds the CSV file into a tabular format

# %%
df = pd.read_csv("data.csv")

# %%
# Display the first 5 rows of the data
df.head(10) # optional parameter, default -> 5
# Out:
#    s.n    name  grade    address  gender
# 0    1  Sharad     10  Kathmandu    Male
# 1    2    John     11  Minnesota    Male
# 2    3   Alice     11     Kansas  Female
# 3    4  Shilpa     10      Delhi  Female
# 4    5    Ajay      9     Mumbai    Male

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['name']
df.name
# Out:
# 0    Sharad
# 1      John
# 2     Alice
# 3    Shilpa
# 4      Ajay
# Name: name, dtype: object

# %%
df['grade']
df.grade
# Out:
# 0    10
# 1    11
# 2    11
# 3    10
# 4     9
# Name: grade, dtype: int64

# %%
# Selecting Multiple Columns
df[['name', 'grade']]
# Out:
#      name  grade
# 0  Sharad     10
# 1    John     11
# 2   Alice     11
# 3  Shilpa     10
# 4    Ajay      9

# %%
display(df['name'])
display(df[['name']])
# Out:
# 0    Sharad
# 1      John
# 2     Alice
# 3    Shilpa
# 4      Ajay
# Name: name, dtype: object
#      name
# 0  Sharad
# 1    John
# 2   Alice
# 3  Shilpa
# 4    Ajay

# %%
# Selecting a cell in dataframe
df.loc[0, ['name', 'grade']]
# Out:
# name     Sharad
# grade        10
# Name: 0, dtype: object

# %%
# Selecting a cell based on index on both row and column
df.iloc[0, 1]

# Multiple Columns
df.iloc[0, [1, 2]]
# Out:
# name     Sharad
# grade        10
# Name: 0, dtype: object

# %%
# Slicing
df.iloc[[0,1], [0,1]]
# Out:
#    s.n    name
# 0    1  Sharad
# 1    2    John

# %%
df.loc[[2,3], ['gender', 'name']]
# Out:
#    gender    name
# 2  Female   Alice
# 3  Female  Shilpa

# %%
df['gender']
# Out:
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4      Male
# Name: gender, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   s.n      5 non-null      int64
#  1   name     5 non-null      object
#  2   grade    5 non-null      int64
#  3   address  5 non-null      object
#  4   gender   5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes
