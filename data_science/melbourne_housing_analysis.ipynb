# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Melbourne_housing_FULL.csv")

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.shape
# Out:
# (34857, 21)

# %%
df.columns.to_list()
# Out:
# ['Suburb',
#  'Address',
#  'Rooms',
#  'Type',
#  'Price',
#  'Method',
#  'SellerG',
#  'Date',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'CouncilArea',
#  'Lattitude',
#  'Longtitude',
#  'Regionname',
#  'Propertycount']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
df[['Car', 'Bathroom', 'Rooms', 'Landsize']].describe().round()
# Out:
#            Car  Bathroom    Rooms  Landsize
# count  26129.0   26631.0  34857.0   23047.0
# mean       2.0       2.0      3.0     594.0
# std        1.0       1.0      1.0    3399.0
# min        0.0       0.0      1.0       0.0
# 25%        1.0       1.0      2.0     224.0
# 50%        2.0       2.0      3.0     521.0
# 75%        2.0       2.0      4.0     670.0
# max       26.0      12.0     16.0  433014.0

# %%
df['YearBuilt'].value_counts().to_frame().reset_index()
# Out:
#      YearBuilt  count
# 0       1970.0   1490
# 1       1960.0   1260
# 2       1950.0   1089
# 3       1980.0    726
# 4       1900.0    606
# ..         ...    ...
# 155     1830.0      1
# 156     2106.0      1
# 157     1897.0      1
# 158     1876.0      1
# 159     1879.0      1
#
# [160 rows x 2 columns]

# %%
df['Regionname'].value_counts().to_frame().reset_index()
# Out:
#                    Regionname  count
# 0       Southern Metropolitan  11836
# 1       Northern Metropolitan   9557
# 2        Western Metropolitan   6799
# 3        Eastern Metropolitan   4377
# 4  South-Eastern Metropolitan   1739
# 5            Eastern Victoria    228
# 6           Northern Victoria    203
# 7            Western Victoria    115

# %%
df['CouncilArea'].value_counts().reset_index()
# Out:
#                        CouncilArea  count
# 0          Boroondara City Council   3675
# 1             Darebin City Council   2851
# 2            Moreland City Council   2122
# 3           Glen Eira City Council   2006
# 4           Melbourne City Council   1952
# 5             Banyule City Council   1861
# 6       Moonee Valley City Council   1791
# 7             Bayside City Council   1764
# 8            Brimbank City Council   1593
# 9              Monash City Council   1466
# 10        Stonnington City Council   1460
# 11        Maribyrnong City Council   1451
# 12       Port Phillip City Council   1280
# 13               Hume City Council   1214
# 14              Yarra City Council   1186
# 15         Manningham City Council   1046
# 16        Hobsons Bay City Council    942
# 17           Kingston City Council    871
# 18         Whittlesea City Council    828
# 19            Wyndham City Council    624
# 20         Whitehorse City Council    618
# ...

# %%
# Mean of rooms
df[['Rooms', 'Car']].mean()
# Out:
# Rooms    3.031012
# Car      1.728845
# dtype: float64

# %%
df['Rooms'].median()
# Out:
# np.float64(3.0)

# %%
df[['Regionname', 'Type']].value_counts().reset_index()
# Out:
#                     Regionname Type  count
# 0        Southern Metropolitan    h   6968
# 1        Northern Metropolitan    h   6489
# 2         Western Metropolitan    h   5199
# 3        Southern Metropolitan    u   3536
# 4         Eastern Metropolitan    h   3438
# 5        Northern Metropolitan    u   2033
# 6   South-Eastern Metropolitan    h   1356
# 7        Southern Metropolitan    t   1332
# 8        Northern Metropolitan    t   1035
# 9         Western Metropolitan    u    946
# 10        Western Metropolitan    t    654
# 11        Eastern Metropolitan    u    548
# 12        Eastern Metropolitan    t    391
# 13  South-Eastern Metropolitan    u    221
# 14            Eastern Victoria    h    216
# 15           Northern Victoria    h    199
# 16  South-Eastern Metropolitan    t    162
# 17            Western Victoria    h    113
# 18            Eastern Victoria    u      7
# 19            Eastern Victoria    t      5
# 20           Northern Victoria    u      3
# ...

# %%
# Bivariate Analysis
df[['Type', 'Method']].value_counts().reset_index()
# Out:
#    Type Method  count
# 0     h      S  14047
# 1     u      S   3816
# 2     h     SP   3293
# 3     h     PI   3214
# 4     h     VB   1942
# 5     t      S   1881
# 6     u     SP   1292
# 7     u     PI   1031
# 8     h     SN   1015
# 9     u     VB    786
# 10    t     PI    605
# 11    t     SP    510
# 12    t     VB    380
# 13    u     SN    191
# 14    h     PN    182
# 15    h     SA    155
# 16    t     SN    111
# 17    h      W    104
# 18    u     PN     77
# 19    u      W     56
# 20    t     PN     49
# 21    u     SA     44
# 22    h     SS     28
# 23    t     SA     27
# 24    t      W     13
# 25    t     SS      4
# 26    u     SS      4

# %%
# How to handle NA values
# How to create a custom column based on value of other columns

# %%
# NA Values
# Empty values, Null Values, NaN values
# 0 is not a an NA value

# How to identify NA values in dataset
# " ", NaN, null

# %%
# How to handle NA or missing values?
# 1. Remove the row
# 2. Remove the column
# 3. Impute or fill the value with other values

# %%
# If more than half of the data is missing in a column for all rows, then remove the column
# If there are very few rows with missing value in a column, then remove the row (bad choice)
# If a row contains multiple missing values in multiple columns, then remove the row (best choice)
# otherwise fill the data with mode or median or mean

# %%
# Removing the column
# original df -> make another df
# remove the column in the original df itself

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
# Method 1-> make a copy
cleaned_df = df.drop(columns=['YearBuilt', 'BuildingArea'])

# %%
display(df.columns)
cleaned_df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount'],
#       dtype='object')

# %%
# Method 2 -> Drop the column in original dataframe
# df = df.drop(columns=['YearBuilt', 'BuildingArea'])
df.drop(columns=['YearBuilt', 'BuildingArea'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    34854 non-null  object
#  15  Lattitude      26881 non-null  float64
#  16  Longtitude     26881 non-null  float64
# ...

# %%
df['Distance'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34852    False
# 34853    False
# 34854    False
# 34855    False
# 34856    False
# Name: Distance, Length: 34857, dtype: bool

# %%
# Check which row has empty data in Distance column
df[df['Distance'].isna()]
# Out:
#             Suburb       Address  Rooms Type     Price Method SellerG  \
# 29483  Fawkner Lot  1/3 Brian St      3    h  616000.0     SP    Brad
#
#             Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 29483  6/01/2018       NaN       NaN       NaN       NaN  NaN       NaN
#
#       CouncilArea  Lattitude  Longtitude Regionname  Propertycount
# 29483         NaN        NaN         NaN        NaN            NaN

# %%
# Dropping row using index
df.drop(29483, inplace=True)

# %%
df[df['Distance'].isna()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34856 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34856 non-null  object
#  1   Address        34856 non-null  object
#  2   Rooms          34856 non-null  int64
#  3   Type           34856 non-null  object
#  4   Price          27246 non-null  float64
#  5   Method         34856 non-null  object
#  6   SellerG        34856 non-null  object
#  7   Date           34856 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    34854 non-null  object
#  15  Lattitude      26881 non-null  float64
#  16  Longtitude     26881 non-null  float64
# ...

# %%
df[df['CouncilArea'].isna()]
# Out:
#            Suburb           Address  Rooms Type     Price Method SellerG  \
# 18523   Footscray  2/16 Stafford St      2    u  710000.0      S     Jas
# 26888  Camberwell   2/3 Kingsley St      2    h  825000.0     VB  Jellis
#
#              Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 18523  15/07/2017       5.1    3011.0       NaN       NaN  NaN       NaN
# 26888  11/11/2017       7.7    3124.0       NaN       NaN  NaN       NaN
#
#       CouncilArea  Lattitude  Longtitude Regionname  Propertycount
# 18523         NaN        NaN         NaN        NaN            NaN
# 26888         NaN        NaN         NaN        NaN            NaN

# %%
df.drop([18523, 26888], inplace=True)

# %%
df[df['CouncilArea'].isna()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34854 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34854 non-null  object
#  1   Address        34854 non-null  object
#  2   Rooms          34854 non-null  int64
#  3   Type           34854 non-null  object
#  4   Price          27244 non-null  float64
#  5   Method         34854 non-null  object
#  6   SellerG        34854 non-null  object
#  7   Date           34854 non-null  object
#  8   Distance       34854 non-null  float64
#  9   Postcode       34854 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    34854 non-null  object
#  15  Lattitude      26881 non-null  float64
#  16  Longtitude     26881 non-null  float64
# ...

# %%
series_1 = pd.Series([1, np.nan, 3])

# %%
series_1.isna()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
df[df['Car'].isna()]
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 15       Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16       Abbotsford      18a Mollison St      2    t   745000.0      S
# 19       Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21       Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22       Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...             ...                  ...    ...  ...        ...    ...
# 34840  Williamstown      3/2 Thompson St      2    u   520000.0     VB
# 34842  Williamstown        34 Twyford St      3    h  1400000.0     SP
# 34844       Windsor     4/16 Lewisham Rd      1    u   440000.0     SP
# 34851    Yarraville        78 Bayview Rd      3    h  1101000.0      S
# 34855    Yarraville     12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
filter = (
    df['Bedroom2'].isna() 
    & df['Bathroom'].isna() 
    & df['Car'].isna() 
    & df['Landsize'].isna() 
    & df['Lattitude'].isna() 
    & df['Longtitude'].isna()
)

# %%
df[filter]
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 15       Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16       Abbotsford      18a Mollison St      2    t   745000.0      S
# 19       Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21       Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22       Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...             ...                  ...    ...  ...        ...    ...
# 34838  Williamstown   11/81 Melbourne Rd      2    u   450000.0     SP
# 34839  Williamstown     24/18 Station Rd      2    u   475000.0     SP
# 34840  Williamstown      3/2 Thompson St      2    u   520000.0     VB
# 34844       Windsor     4/16 Lewisham Rd      1    u   440000.0     SP
# 34855    Yarraville     12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
indexes_to_drop = df[filter].index.to_list()
indexes_to_drop
# Out:
# [15,
#  16,
#  19,
#  21,
#  22,
#  27,
#  33,
#  34,
#  45,
#  46,
#  52,
#  60,
#  62,
#  65,
#  74,
#  75,
#  76,
#  77,
#  78,
#  84,
#  87,
#  89,
#  91,
#  92,
#  93,
#  95,
#  97,
#  99,
#  107,
#  111,
#  115,
#  121,
#  123,
#  124,
#  125,
#  126,
#  127,
#  130,
#  131,
#  132,
#  146,
#  184,
#  198,
#  200,
#  207,
#  208,
#  211,
#  212,
#  222,
#  223,
#  225,
#  240,
#  252,
#  254,
#  256,
#  266,
#  273,
#  286,
#  287,
#  291,
#  293,
#  296,
#  297,
#  298,
#  300,
#  302,
#  303,
#  304,
#  305,
#  307,
#  308,
#  311,
#  312,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  323,
#  324,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  336,
#  341,
#  345,
#  348,
#  351,
#  352,
#  354,
#  357,
#  358,
#  362,
#  363,
#  370,
#  373,
#  374,
#  379,
#  384,
#  389,
#  398,
#  417,
#  419,
#  423,
#  433,
#  442,
#  443,
#  451,
#  462,
#  463,
#  464,
#  474,
#  477,
#  489,
#  498,
#  511,
#  513,
#  518,
#  524,
#  529,
#  532,
#  535,
# ...

# %%
df.drop(indexes_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26907 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         26907 non-null  object
#  1   Address        26907 non-null  object
#  2   Rooms          26907 non-null  int64
#  3   Type           26907 non-null  object
#  4   Price          21015 non-null  float64
#  5   Method         26907 non-null  object
#  6   SellerG        26907 non-null  object
#  7   Date           26907 non-null  object
#  8   Distance       26907 non-null  float64
#  9   Postcode       26907 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    26907 non-null  object
#  15  Lattitude      26881 non-null  float64
#  16  Longtitude     26881 non-null  float64
# ...

# %%
df[df['Car'].isna()]
# Out:
#                 Suburb           Address  Rooms Type      Price Method  \
# 26          Abbotsford        22 Park St      4    h  1985000.0      S
# 47          Abbotsford        8b Park St      4    h        NaN     PI
# 54          Abbotsford     17/1 Abbot St      3    t   962000.0     SP
# 64          Abbotsford        22 Park St      4    h        NaN      W
# 220         Alphington     17 Lowther St      3    h  1361000.0      S
# ...                ...               ...    ...  ...        ...    ...
# 34678          Rosanna    31 Kathleen St      4    h  1125000.0     PI
# 34702  South Melbourne  445 Clarendon St      3    h  1720000.0      S
# 34788        Thornbury       41 Gooch St      2    h  1105000.0      S
# 34842     Williamstown     34 Twyford St      3    h  1400000.0     SP
# 34851       Yarraville     78 Bayview Rd      3    h  1101000.0      S
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
filter = df['Bedroom2'].isna() & df['Bathroom'].isna() & df['Car'].isna() & df['Landsize'].isna()

# %%
indexes_to_drop = df[filter].index.to_list()
len(indexes_to_drop)
# Out:
# 260

# %%
df.drop(indexes_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26647 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         26647 non-null  object
#  1   Address        26647 non-null  object
#  2   Rooms          26647 non-null  int64
#  3   Type           26647 non-null  object
#  4   Price          20812 non-null  float64
#  5   Method         26647 non-null  object
#  6   SellerG        26647 non-null  object
#  7   Date           26647 non-null  object
#  8   Distance       26647 non-null  float64
#  9   Postcode       26647 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    26647 non-null  object
#  15  Lattitude      26621 non-null  float64
#  16  Longtitude     26621 non-null  float64
# ...

# %%
df[df['Car'].isna()]
# Out:
#                 Suburb           Address  Rooms Type      Price Method  \
# 19752         Armadale   9/61 Kooyong Rd      2    u   450000.0     VB
# 19759       Ascot Vale    132 The Parade      3    h   985000.0      S
# 19832   Brunswick East       18 Ethel St      2    h  1023000.0      S
# 19875     Clifton Hill     34 Fenwick St      3    h  1436000.0      S
# 19903  Dandenong North      86 McFees Rd      3    h   585000.0      S
# ...                ...               ...    ...  ...        ...    ...
# 34667         Richmond       67B Lord St      2    u        NaN      S
# 34702  South Melbourne  445 Clarendon St      3    h  1720000.0      S
# 34788        Thornbury       41 Gooch St      2    h  1105000.0      S
# 34842     Williamstown     34 Twyford St      3    h  1400000.0     SP
# 34851       Yarraville     78 Bayview Rd      3    h  1101000.0      S
#
#         SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df['Car'].median()
# Out:
# np.float64(2.0)

# %%
df['Car'].mean()
# Out:
# np.float64(1.7288453442535114)

# %%
# Fill the value
df.loc[df['Car'].isna(), 'Car'] = df['Car'].median()

# %%
# Check again
df.loc[df['Car'].isna()]
# Out:
# Empty DataFrame
# Columns: [Suburb, Address, Rooms, Type, Price, Method, SellerG, Date, Distance, Postcode, Bedroom2, Bathroom, Car, Landsize, CouncilArea, Lattitude, Longtitude, Regionname, Propertycount]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26647 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         26647 non-null  object
#  1   Address        26647 non-null  object
#  2   Rooms          26647 non-null  int64
#  3   Type           26647 non-null  object
#  4   Price          20812 non-null  float64
#  5   Method         26647 non-null  object
#  6   SellerG        26647 non-null  object
#  7   Date           26647 non-null  object
#  8   Distance       26647 non-null  float64
#  9   Postcode       26647 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26647 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    26647 non-null  object
#  15  Lattitude      26621 non-null  float64
#  16  Longtitude     26621 non-null  float64
# ...

# %%
df.loc[df['Bedroom2'].isna()]
# Out:
#                Suburb          Address  Rooms Type      Price Method  \
# 22695  Port Melbourne       31 Ross St      2    h        NaN      S
# 24807         Wollert  39 Birchmore Rd      4    h   335000.0     PI
# 26177         Mentone  7/3 Childers St      1    u   385000.0      S
# 27157         Mentone       2 Ovens Ct      5    h  1200000.0     PI
# 29197    Williamstown      87 Power St      3    h  1145000.0      S
# 34114      Cheltenham   3/2 Bayliss St      2    t   682000.0      S
# 34149     Craigieburn  9 Braveheart Rd      3    h   438000.0      S
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 22695       Marshall  23/09/2017       3.5    3207.0       NaN       NaN  2.0
# 24807  hockingstuart  14/10/2017      25.5    3750.0       NaN       NaN  2.0
# 26177        O'Brien  28/10/2017      20.0    3194.0       NaN       NaN  2.0
# 27157  hockingstuart  11/11/2017      20.0    3194.0       NaN       NaN  2.0
# ...

# %%
df.loc[df['Bedroom2'].isna(), 'Bedroom2'] = np.round(df['Bedroom2'].median(), 0)
df.loc[df['Bathroom'].isna(), 'Bathroom'] = np.round(df['Bathroom'].median(), 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26647 entries, 0 to 34856
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         26647 non-null  object
#  1   Address        26647 non-null  object
#  2   Rooms          26647 non-null  int64
#  3   Type           26647 non-null  object
#  4   Price          20812 non-null  float64
#  5   Method         26647 non-null  object
#  6   SellerG        26647 non-null  object
#  7   Date           26647 non-null  object
#  8   Distance       26647 non-null  float64
#  9   Postcode       26647 non-null  float64
#  10  Bedroom2       26647 non-null  float64
#  11  Bathroom       26647 non-null  float64
#  12  Car            26647 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  CouncilArea    26647 non-null  object
#  15  Lattitude      26621 non-null  float64
#  16  Longtitude     26621 non-null  float64
# ...

# %%
df['Lattitude'].value_counts()
# Out:
# Lattitude
# -37.83610    25
# -37.84240    22
# -37.79560    20
# -37.81980    19
# -37.84140    18
#              ..
# -37.91508     1
# -37.86338     1
# -37.89039     1
# -37.81408     1
# -37.81551     1
# Name: count, Length: 13317, dtype: int64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount'],
#       dtype='object')

# %%
df[['Rooms', 'Bedroom2', 'Bathroom']]
# Out:
#        Rooms  Bedroom2  Bathroom
# 0          2       2.0       1.0
# 1          2       2.0       1.0
# 2          2       2.0       1.0
# 3          3       3.0       2.0
# 4          3       3.0       2.0
# ...      ...       ...       ...
# 34851      3       3.0       1.0
# 34852      4       4.0       1.0
# 34853      2       2.0       2.0
# 34854      2       2.0       1.0
# 34856      2       2.0       1.0
#
# [26647 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount'],
#       dtype='object')

# %%
columns_list = df.columns.to_list()

# %%
columns_dict = {}

# %%
for column in columns_list:
    columns_dict[column] = column.lower()

# %%
columns_dict
# Out:
# {'Suburb': 'suburb',
#  'Address': 'address',
#  'Rooms': 'rooms',
#  'Type': 'type',
#  'Price': 'price',
#  'Method': 'method',
#  'SellerG': 'sellerg',
#  'Date': 'date',
#  'Distance': 'distance',
#  'Postcode': 'postcode',
#  'Bedroom2': 'bedroom2',
#  'Bathroom': 'bathroom',
#  'Car': 'car',
#  'Landsize': 'landsize',
#  'CouncilArea': 'councilarea',
#  'Lattitude': 'lattitude',
#  'Longtitude': 'longtitude',
#  'Regionname': 'regionname',
#  'Propertycount': 'propertycount'}

# %%
columns_dict["Longtitude"] = "longitude"

# %%
columns_dict
# Out:
# {'Suburb': 'suburb',
#  'Address': 'address',
#  'Rooms': 'rooms',
#  'Type': 'type',
#  'Price': 'price',
#  'Method': 'method',
#  'SellerG': 'sellerg',
#  'Date': 'date',
#  'Distance': 'distance',
#  'Postcode': 'postcode',
#  'Bedroom2': 'bedroom2',
#  'Bathroom': 'bathroom',
#  'Car': 'car',
#  'Landsize': 'landsize',
#  'CouncilArea': 'councilarea',
#  'Lattitude': 'lattitude',
#  'Longtitude': 'longitude',
#  'Regionname': 'regionname',
#  'Propertycount': 'propertycount'}

# %%
df = df.rename(columns=columns_dict)

# %%
df
# Out:
#            suburb             address  rooms type      price method  sellerg  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
df.columns
# Out:
# Index(['suburb', 'address', 'rooms', 'type', 'price', 'method', 'sellerg',
#        'date', 'distance', 'postcode', 'bedroom2', 'bathroom', 'car',
#        'landsize', 'councilarea', 'lattitude', 'longitude', 'regionname',
#        'propertycount'],
#       dtype='object')

# %%
df['totalrooms'] = df['rooms'] + df['bedroom2'] + df['bathroom']

# %%
df
# Out:
#            suburb             address  rooms type      price method  sellerg  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
# Change the columns to integer
columns_to_change = ['rooms', 'bedroom2', 'bathroom', 'car', 'totalrooms', 'propertycount']

for column in columns_to_change:
    df[column] = df[column].astype(int)

# Categorial Columns
df[['type', 'method', 'regionname']] = df[['type','method', 'regionname']].astype('category')

# %%
df
# Out:
#            suburb             address  rooms type      price method  sellerg  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
df.dtypes
# Out:
# suburb             object
# address            object
# rooms               int64
# type             category
# price             float64
# method           category
# sellerg            object
# date               object
# distance          float64
# postcode          float64
# bedroom2            int64
# bathroom            int64
# car                 int64
# landsize          float64
# councilarea        object
# lattitude         float64
# longitude         float64
# regionname       category
# propertycount       int64
# totalrooms          int64
# dtype: object

# %%
df.loc[(df['method'] == 'SS') & ~(df['price'].isna())]
# Out:
# Empty DataFrame
# Columns: [suburb, address, rooms, type, price, method, sellerg, date, distance, postcode, bedroom2, bathroom, car, landsize, councilarea, lattitude, longitude, regionname, propertycount, totalrooms]
# Index: []

# %%
ss_rows = df.loc[df['method'] == 'SS'].index.to_list()

# %%
df = df.drop(ss_rows)

# %%
df
# Out:
#            suburb             address  rooms type      price method  sellerg  \
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
df.loc[(df['method'] == 'VB') & ~(df['price'].isna())]
# Out:
#              suburb             address  rooms type      price method  \
# 6        Abbotsford         55a Park St      4    h  1600000.0     VB
# 23       Abbotsford  411/8 Grosvenor St      2    u   700000.0     VB
# 24       Abbotsford     40 Nicholson St      3    h  1350000.0     VB
# 67     Airport West       50 Bedford St      3    h   730000.0     VB
# 73     Airport West    2/49 McIntosh St      2    u   500000.0     VB
# ...             ...                 ...    ...  ...        ...    ...
# 34766  Surrey Hills       56 Croydon Rd      3    h  1750000.0     VB
# 34789     Thornbury        98 Hutton St      3    h  1200000.0     VB
# 34802       Vermont      19 Caldwell Rd      4    h   900000.0     VB
# 34817      Watsonia       32 Kenmare St      3    h   840000.0     VB
# 34841  Williamstown       5 Thompson St      2    h   940000.0     VB
#
#          sellerg        date  distance  postcode  bedroom2  bathroom  car  \
# ...

# %%
df[df['price'].isna()]['method'].value_counts()
# Out:
# method
# S     1759
# PI    1164
# SP    1148
# SN    1075
# VB     273
# PN     229
# W      129
# SA      29
# SS       0
# Name: count, dtype: int64

# %%
# Categorical Medians
method_medians = df.groupby('method').agg({'price':'median'}).reset_index()
# Out:
# /var/folders/7w/9vr0vf2x7zx4_f925bn5kmc80000gq/T/ipykernel_1935/2478130138.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   method_medians = df.groupby(['method', 'regionname']).agg({'price':'median'}).reset_index()

# %%
method_medians
# Out:
#    method                  regionname     price
# 0      PI        Eastern Metropolitan  975000.0
# 1      PI            Eastern Victoria  975000.0
# 2      PI       Northern Metropolitan  975000.0
# 3      PI           Northern Victoria  975000.0
# 4      PI  South-Eastern Metropolitan  975000.0
# ..    ...                         ...       ...
# 67      W           Northern Victoria       NaN
# 68      W  South-Eastern Metropolitan       NaN
# 69      W       Southern Metropolitan       NaN
# 70      W        Western Metropolitan       NaN
# 71      W            Western Victoria       NaN
#
# [72 rows x 3 columns]

# %%
# df left join method_medians
df = pd.merge(df, method_medians, how='left', on='method')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[116], line 2
#       1 # df left join method_medians
# ----> 2 df = pd.merge(df, method_medians, how='sharad', on='method')
#
# File ~/Desktop/python_tutorial/data_science/.venv/lib/python3.9/site-packages/pandas/core/reshape/merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~/Desktop/python_tutorial/data_science/.venv/lib/python3.9/site-packages/pandas/core/reshape/merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
# ...

# %%
df = df.rename(columns={"price_x":"price", "price_y":"medianprice"})

# %%
df
# Out:
#            suburb             address  rooms type      price method  sellerg  \
# 0      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 1      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 2      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 3      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 4      Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 26613  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 26614  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 26615  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 26616  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 26617  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
df.loc[df['price'].isna(), 'price'] = df['medianprice']

# %%
df
# Out:
#            suburb             address  rooms type      price method  sellerg  \
# 0      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 1      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 2      Abbotsford  18/659 Victoria St      3    u  1050000.0     VB   Rounds
# 3      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 4      Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 26613  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 26614  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 26615  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 26616  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 26617  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
df = df.drop(columns='medianprice')

# %%
df.loc[df['price'].isna()]['method'].value_counts()
# Out:
# method
# SN    1075
# PN     229
# W      129
# PI       0
# S        0
# SA       0
# SP       0
# SS       0
# VB       0
# Name: count, dtype: int64

# %%
# Dropping rows where method is either SN, PN or W
df = df.drop(df.loc[df['method'].isin(['SN', 'PN', 'W'])].index.to_list())

# %%
df.loc[df['price'].isna()]['method'].value_counts()
# Out:
# method
# PI    0
# PN    0
# S     0
# SA    0
# SN    0
# SP    0
# SS    0
# VB    0
# W     0
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25185 entries, 0 to 26617
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   suburb         25185 non-null  object
#  1   address        25185 non-null  object
#  2   rooms          25185 non-null  int64
#  3   type           25185 non-null  category
#  4   price          25185 non-null  float64
#  5   method         25185 non-null  category
#  6   sellerg        25185 non-null  object
#  7   date           25185 non-null  object
#  8   distance       25185 non-null  float64
#  9   postcode       25185 non-null  float64
#  10  bedroom2       25185 non-null  int64
#  11  bathroom       25185 non-null  int64
#  12  car            25185 non-null  int64
#  13  landsize       21755 non-null  float64
#  14  councilarea    25185 non-null  object
#  15  lattitude      25159 non-null  float64
#  16  longitude      25159 non-null  float64
# ...
