# %% [raw]
# What is Machine Learning?
#
# It is a method where machine learns patterns from the data instead of being explicitly programmed.
# Major Uses:
# 1. Automation of decision
# 2. Handling of complex patterns
# 3. Improving accuracy of system over time
# 4. Used in finance, healthcare, marketing, self-driving, recommendation systems.
#
#
# Traditional Programming vs Machine Learnings
# Traditional Programming: Rules -> Output
# Machine Learning: Data -> Model -> Output

# %% [raw]
# Types of Machine Learning:
# 1. Supervised Learning
#     a. Input + Output
#     b. Predict Labels or Predict Values
#     c. Example: Linear Regression, House Price Detection, Spam Detection, Decision Tree
#
# 2. Unsupervised Learning
#     a. No output labels
#     b. Finds hidden patterns
#     c. Example: KNN (K neighbors classification), PCA (Principal Component Analysis), Clustering
#
# 3. Reinforcement Learning
#     a. Agent learns by interacting with environment
#     b. Rewards & Penalties
#     c. Used in robotics, games, navigation

# %% [raw]
# Machine Learning Workflow
#
# 1. Problem Definition
# 2. Data Collection
# 3. Data Cleaning
# 4. Feature Engineering
# 5. Model Training
# 6. Evaluation
# 7. Deployment
# 8. Monitoring

# %% [raw]
# Feature Engineering
# 1. Standardization
# 2. Normalization
# 3. Encoding

# %% [raw]
# How to train a ML model?
#
# Supervised Learning
# Dataset -> X, y
# X -> features (multiple columns) (Also known as Independent Variable)
# y -> labels (only one column - series) (Also known as Dependent Variable)
#
# X -> X_train, X_test
# y -> y_train, y_test
#
# train -> fitting model
# test -> measuring performance of the model

# %%
# %pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/ssharma/Desktop/python_tutorial/data_science/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/ssharma/Desktop/python_tutorial/data_science/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# %pip list
# Out:
# Package             Version
# ------------------- -----------
# appnope             0.1.4
# asttokens           3.0.0
# comm                0.2.3
# contourpy           1.3.0
# cycler              0.12.1
# debugpy             1.8.17
# decorator           5.2.1
# exceptiongroup      1.3.0
# executing           2.2.1
# fonttools           4.60.1
# importlib_metadata  8.7.0
# importlib_resources 6.5.2
# ipykernel           6.31.0
# ipython             8.18.1
# jedi                0.19.2
# joblib              1.5.2
# jupyter_client      8.6.3
# jupyter_core        5.8.1
# kiwisolver          1.4.7
# matplotlib          3.9.4
# matplotlib-inline   0.2.1
# nest-asyncio        1.6.0
# numpy               1.26.4
# packaging           25.0
# pandas              2.3.3
# parso               0.8.5
# pexpect             4.9.0
# pillow              11.3.0
# pip                 21.2.4
# platformdirs        4.4.0
# prompt_toolkit      3.0.52
# psutil              7.1.3
# ptyprocess          0.7.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X = np.random.rand(100, 1) * 10
X
# Out:
# array([[5.92490952],
#        [1.28802313],
#        [8.04358613],
#        [1.43862348],
#        [3.61251085],
#        [5.23920156],
#        [2.3446645 ],
#        [4.01228012],
#        [5.77263637],
#        [3.95480865],
#        [5.99568644],
#        [8.70973355],
#        [3.0648113 ],
#        [9.2319564 ],
#        [8.87713958],
#        [8.48470714],
#        [7.84248661],
#        [8.33236807],
#        [7.07459263],
#        [8.87671593],
#        [2.39582503],
#        [0.93838248],
#        [5.25009765],
#        [0.66702591],
#        [2.39821301],
#        [4.12252581],
#        [9.77506513],
#        [7.68476885],
#        [0.77607907],
#        [6.03247202],
#        [5.79502414],
#        [6.84534356],
#        [9.59843917],
#        [9.80884419],
#        [2.80395239],
#        [3.02531895],
#        [9.22412754],
#        [3.14595833],
#        [5.52706768],
#        [5.79589237],
#        [5.31054697],
#        [9.7255968 ],
#        [7.27285483],
# ...

# %%
y = 3*X + 4 + np.random.randn(100, 1)

# %%
y
# Out:
# array([[23.12668283],
#        [ 9.20270357],
#        [26.85009885],
#        [ 8.17267985],
#        [15.16230214],
#        [19.86296639],
#        [11.37125898],
#        [14.58062876],
#        [21.42556851],
#        [16.36911491],
#        [23.3141652 ],
#        [30.6921408 ],
#        [11.27014205],
#        [30.17427633],
#        [30.4404264 ],
#        [31.15239644],
#        [28.43391907],
#        [31.26578365],
#        [26.40350049],
#        [29.94890837],
#        [11.73246072],
#        [ 6.9853454 ],
#        [20.13705257],
#        [ 5.88055458],
#        [12.84596113],
#        [17.62923289],
#        [35.5458124 ],
#        [25.6760643 ],
#        [ 4.76854872],
#        [22.98492717],
#        [20.42997788],
#        [25.36499326],
#        [33.43280798],
#        [32.15846586],
#        [12.28502508],
#        [13.90125538],
#        [30.9027978 ],
#        [13.23244889],
#        [20.36918837],
#        [20.31271284],
#        [20.19551453],
# ...

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[2.98000711]])

# %%
model.intercept_
# Out:
# array([4.20225344])

# %%
plt.scatter(X, y, color='green')
plt.plot(X, model.predict(X), color='red')
plt.xlabel("X Feature")
plt.ylabel("Y Feature")
plt.title("Linear Regression")
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("data/advertising.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv("data/advertising.csv")
#
# File ~/Desktop/python_tutorial/data_science/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
